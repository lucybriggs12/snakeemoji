# %% [markdown]
# ## Midterm
# ### Research Question: Where do gaps in transit access to grocery stores exist for residents age 65+ in the city of Los Angeles?
# #### This notebook: Looking at density of transit stops as they compare to density of seniors.
# ##### Author: Carolyn Pugh
# ##### Team: Monisha Reginald, Lucy Briggs, Adriana Ochoa

# %% [markdown]
# ### Data Sources:
# ##### Bus Lines and Stops:
# LA Metro - Link: https://developer.metro.net/gis-data/
# LADOT - Link: https://catalog.data.gov/dataset/ladot-dash-and-commuter-express-routes-and-stops
# Big Blue Bus - Link: http://gtfs.bigbluebus.com/
# ##### Metro Lines and Stops:
# LA Metro - Link: https://developer.metro.net/gis-data/
# ##### Census Age Data:
# Social Data Explorer - Link: https://www.socialexplorer.com/reports/socialexplorer/en/report/0cc0f56c-9d1c-11ed-be9e-e30303f780e8
# ##### LA City Boundary:
# LA GeoHub - Link: https://geohub.lacity.org/datasets/city-boundary/explore?location=34.019779%2C-118.412043%2C10.96
# ##### Census Block Group Boundaries:
# LA GeoHub - Link: https://geohub.lacity.org/datasets/lacounty::census-block-groups-2020/explorehttps://geohub.lacity.org/datasets/lacounty::census-block-groups-2020/explore

# %% [markdown]
# ### Part 1: Exploring Transit Data

# %% [markdown]
# Import Libraries

# %%
#import the libraries I will be using below (pandas, geopandas, matplotlib, contextily)
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import requests
import urllib

# %% [markdown]
# ### LA City Blockgroup Boundaries

# %% [markdown]
# First, I need to import two files containing relevant spatial data - a geojson file showing the boundaries of the City of Los Angeles, since that is our geographic focus. Next, a geojson file that contains block groups for the entire County of Los Angeles, since the file with the City boundary does not contain the block group information.

# %%
#reading in the two spatial files and naming dataframes
city_bound = gpd.read_file('City_Boundaries.geojson')
#city_bound has the boundaries of all cities in LA County
blockgroups = gpd.read_file('Census_Block_Groups_2020.geojson')
#blockgroups has hte blockgroup boundaries for all of LA County

# %% [markdown]
# The "city_bound" dataframe has all city boundaries in LA, and I only want to look at the City of LA (not Santa Monica, for example). Therefore I only want a subset of this dataframe.

# %%
#Querying the city boundary dataframe to create a new LA only boundary.
city_boundLA = city_bound.query("CITY_NAME == 'Los Angeles'").copy()

# %% [markdown]
# Next, I will use the "city_boundLA" dataframe to "clip" the LA county blockgroups dataframe, creating a new dataframe that contains blockgroup information for only LA city.

# %%
#Using "clip" to create a mask of the block boundary data and cut out everything that is outside LA city.
cityblockgroups = gpd.clip(blockgroups,city_boundLA)
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/tools/clip.py:67: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   clipped.loc[

# %%
# Save this file because it may be useful for other scripts.
cityblockgroups.to_file('cityblockgroups.geojson')

# %% [markdown]
# ### Read in LA Metro Bus Route Data

# %%
#read in Metro bus lines geojson file and create dataframe
metrobusroute = gpd.read_file('Metro_Bus_Lines.geojson')

# %%
#What columns does it have?
metrobusroute.columns.to_list()
# Out:
# ['OBJECTID',
#  'VAR_ROUTE',
#  'VAR_IDENT',
#  'VAR_DESCR',
#  'VAR_DIREC',
#  'MetroCategory',
#  'MetroBusType',
#  'RouteNumber',
#  'RouteName',
#  'TOOLTIP',
#  'NLA_URL',
#  'geometry']

# %% [markdown]
# I will rename some of these columns to make it more obvious what they represent.

# %%
#Renaming columns for clarity
metrobusroute.rename(columns=
               {'VAR_ROUTE':'Trunk Line',
 'VAR_IDENT':'Identifying Number',
 'VAR_DESCR':'Trip Pattern',
 'MetroCategory': 'Metro Category',
 'MetroBusType':'Metro Bus Type',
 'RouteNumber': 'Route Number',
 'RouteName': 'Route Name'}, inplace = True)
#Displaying first 2 rows as a check
metrobusroute.head(2)
# Out:
#    OBJECTID Trunk Line Identifying Number Trip Pattern  VAR_DIREC  \
# 0         1        603                 N1   END TO END          0
# 1         2        603                 S1   END TO END          1
#
#   Metro Category                  Metro Bus Type  Route Number  \
# 0        ComCirc  Metro Shuttles and Circulators           603
# 1        ComCirc  Metro Shuttles and Circulators           603
#
#                                           Route Name  \
# 0  603 Glendale-Grand Sta Via San Fernando-Rampar...
# 1  603 Glendale-Grand Sta Via San Fernando-Rampar...
#
#                                              TOOLTIP  \
# 0  603 Glendale-Grand Sta Via San Fernando-Rampar...
# 1  603 Glendale-Grand Sta Via San Fernando-Rampar...
#
#                                              NLA_URL  \
# 0  http://www.metro.net/riding/maps/?nla_target=1...
# 1  http://www.metro.net/riding/maps/?nla_target=1...
#
#                                             geometry
# 0  LINESTRING (-118.26462 34.03322, -118.26432 34...
# 1  LINESTRING (-118.26088 34.14528, -118.26088 34...

# %% [markdown]
# ### Read in LA Metro Bus Stop Data - "Stops Serving Lines"
# #### Each stop contains data for each line served by that stop. This will be important for our analysis of what stops are accessible to block groups with high densities of senior residents.

# %%
#Read in file for LA Metro Bus Stops and name a new dataframe, metrobusstops
metrobusstops = gpd.read_file('StopServingLines1022.shp')

# %%
#Renaming columns for clarity
metrobusstops.rename(columns=
               {'STOPNUM':'StopNumber',
 'STOPNAME':'StopName'}, inplace = True)
#Displaying first 5 rows as a check
metrobusstops.head()
# Out:
#    StopNumber                             StopName        LAT        LONG  \
# 0           1                  Paramount / Slauson  33.973248 -118.113113
# 1           3                     Jefferson / 10th  34.025471 -118.328402
# 2           6           120th / Augustus F Hawkins  33.924696 -118.242222
# 3           7  120th / Martin Luther King Hospital  33.924505 -118.240369
# 4          12                    15054 Sherman Way  34.201075 -118.461953
#
#   LINE_DIR1 LINE_DIR2 LINE_DIR3 LINE_DIR4 LINE_DIR5 LINE_DIR6 LINE_DIR7  \
# 0     108-E     265-S      None      None      None      None      None
# 1      35-N      None      None      None      None      None      None
# 2      53-N     120-W      55-N      None      None      None      None
# 3      55-S     120-E      None      None      None      None      None
# 4     162-E      None      None      None      None      None      None
#
#   LINE_DIR8 LINE_DIR9 LINE_DIR10 LINE_DIR11 LINE_DIR12 LINE_DIR13 LINE_DIR14  \
# 0      None      None       None       None       None       None       None
# 1      None      None       None       None       None       None       None
# 2      None      None       None       None       None       None       None
# 3      None      None       None       None       None       None       None
# 4      None      None       None       None       None       None       None
#
#                       geometry
# 0  POINT (-118.11311 33.97325)
# 1  POINT (-118.32840 34.02547)
# 2  POINT (-118.24222 33.92470)
# 3  POINT (-118.24037 33.92451)
# 4  POINT (-118.46195 34.20108)

# %% [markdown]
# ### Pulling in LA DOT Bus Route and Stop Data

# %% [markdown]
# LA DOT provided data in six shapefiles, one file for routes and one for stops for three different bus types

# %% [markdown]
# LA DOT Community Dash:

# %%
#Read in file for LA DOT Community Dash Bus Stops and Routes
communitydash_stops = gpd.read_file('LA_DOT_data/geo_export_16a65b67-8914-4be6-b080-e03f9fdd23a6.shp')
communitydash_route = gpd.read_file('LA_DOT_data/geo_export_6a5115bd-2818-4cdd-bd10-d8ea258b75b7.shp')

# %%
#first row of community dash stop as check
communitydash_stops.head(1)
# Out:
#                                              nla_url  region      regiontype  \
# 0  http://www.ladotbus.com/simple/regions/7/route...     7.0  Community Dash
#
#    routeid         routename routenames    stopid  \
# 0     89.0  Beachwood Canyon         BC  298831.0
#
#                              stopname  stopnumber  \
# 0  Beachwood & Westshire (Southbound)      2401.0
#
#                                              tooltip  \
# 0  Stop: Beachwood & Westshire (Southbound)\nStop...
#
#                       geometry
# 0  POINT (-118.32111 34.11968)

# %%
#plot routes for community dash as check
communitydash_route.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# LA DOT Commuter Express:

# %%
#Read in file for LA DOT Commuter Express Bus Stops and Routes
commuterexpress_route = gpd.read_file('LA_DOT_data/geo_export_1b588cc2-b98f-42a6-8207-e6df6af67c22.shp')
commuterexpress_stops = gpd.read_file('LA_DOT_data/geo_export_6d784597-ba4b-4a1a-8e74-4ca9e9758280.shp')

# %%
#plot routes for Commuter Express as check
commuterexpress_route.plot()
# Out:
# <AxesSubplot: >

# %%
#first row of Commuter Express stop as check
commuterexpress_stops.head(1)
# Out:
#                                              nla_url  region  \
# 0  http://www.ladotbus.com/simple/regions/8/route...     8.0
#
#          regiontype  routeid           routename          routenames  \
# 0  Commuter Express     12.0  CE142 - Long Beach  CE142 - Long Beach
#
#      stopid                    stopname  stopnumber  \
# 0  431166.0  Ports O'Call & Sampson Way      8800.0
#
#                                              tooltip  \
# 0  Stop: Ports O'Call & Sampson Way\nStop No: 880...
#
#                       geometry
# 0  POINT (-118.27780 33.73204)

# %% [markdown]
# LA DOT Downtown DASH

# %%
#Read in file for LA DOT downtown dash files
downtowndash_route = gpd.read_file('LA_DOT_data/geo_export_247776de-aafe-44c0-9cbd-03d1931ad720.shp')
downtowndash_stops = gpd.read_file('LA_DOT_data/geo_export_d09ae2e0-bede-462e-996d-3f4e9eb096e2.shp')

# %%
#first row of downtown dashs stop as check
downtowndash_stops.head(1)
# Out:
#                                              nla_url  region     regiontype  \
# 0  http://www.ladotbus.com/simple/regions/6/route...     6.0  Downtown Dash
#
#    routeid routename routenames   stopid                 stopname  stopnumber  \
# 0     40.0   Route A          A  91421.0  7th & Bixel (Westbound)      6153.0
#
#                                              tooltip  \
# 0  Stop: 7th & Bixel (Westbound)\nStop No: 6153\n...
#
#                       geometry
# 0  POINT (-118.26400 34.05081)

# %%
#plot routes for downtown dash as check
downtowndash_route.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Getting Big Blue Bus Data

# %%
#read in shapefile and create dataframe
BBB_stops = gpd.read_file('BigBlueBusdata/stops.shp')
#print first row as check
BBB_stops.head(1)
# Out:
#   stop_id stop_code                  stop_name  \
# 0    1145      2768  SUNSET EB & MARQUEZ PL FS
#
#                            stop_desc                     geometry
# 0  17100 W SUNSET BLVD & MARQUEZ AVE  POINT (-118.54889 34.04185)

# %%
#read in routes shapefile and create dataframe
BBB_routes = gpd.read_file('BigBlueBusdata/shapes.shp')
#plot as check
BBB_routes.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Clipping Dataframes to get only LA City

# %% [markdown]
# I will use the LA city boundary dataframe to create new dataframes for both bus routes and bus stops that are specific to the City.

# %%
#Using "clip" to create a mask of the city boundary data and cut out bus stops that are outside the LA city boundary.
citymetrostops = gpd.clip(metrobusstops,city_boundLA)

# %%
#Using "clip" to create a mask of the city boundary data and cut out bus route data that is outside the LA city boundary.
citybusroute = gpd.clip(metrobusroute,city_boundLA)
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/tools/clip.py:67: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   clipped.loc[

# %%
#First I need to edit the CRS of LA DOT datasets to match that of the rest of my datasets.
communitydash_stops = communitydash_stops.to_crs(4326)
communitydash_route = communitydash_route.to_crs(4326)
commuterexpress_route = commuterexpress_route.to_crs(4326)
commuterexpress_stops = commuterexpress_stops.to_crs(4326)
downtowndash_route = downtowndash_route.to_crs(4326)
downtowndash_stops = downtowndash_stops.to_crs(4326)

# %%
#Clipping community DASH bus dataframes to include only LA City
community_citydot_stops = gpd.clip(communitydash_stops,city_boundLA)
community_citydot_route = gpd.clip(communitydash_route,city_boundLA)
#Clipping Commuter DASH bus dataframes to include only LA City
commuter_citydot_route = gpd.clip(commuterexpress_route,city_boundLA)
commuter_citydot_stops = gpd.clip(commuterexpress_stops,city_boundLA)
#Clipping Downtown DASH bus dataframes to include only LA City
downtown_citydot_route = gpd.clip(downtowndash_route,city_boundLA)
downtown_citydot_stops = gpd.clip(downtowndash_stops,city_boundLA)

# %%
#Clipping Big Blue Bus dataframe to include only LA city stops
BBB_stops_city = gpd.clip(BBB_stops, city_boundLA)
BBB_routes_city = gpd.clip(BBB_routes, city_boundLA)

# %% [markdown]
# ### Adding in LA Metro Rail Data

# %% [markdown]
# Import LA metro stop data

# %%
#import the Data 
metrorailstops = gpd.read_file('MetroRailStopsdata/Metro_Rail_Lines_Stops.geojson')
#clip to city boundaries
citymetrorailstops = gpd.clip(metrorailstops,city_boundLA)

# %% [markdown]
# ### Now I will create a dataframe with all bus and metro stops.

# %% [markdown]
# Let's start with LA DOT, and combine the different dataframes.

# %%
#try to create dataframe with all the transit stop data, starting with LA DOT
#append community dash to commuter express and create new dataframe
data = [community_citydot_stops, commuter_citydot_stops]
df2 = pd.concat(data)
#append downtown dash to new dataframe
data2 = [df2, downtown_citydot_stops]
LADOTcitystops = pd.concat(data2)
#check by displaying sample rows
LADOTcitystops.sample(6)
# Out:
#                                                nla_url  region  \
# 180  http://www.ladotbus.com/simple/regions/6/route...     6.0
# 916  http://www.ladotbus.com/simple/regions/8/route...     8.0
# 913  http://www.ladotbus.com/simple/regions/7/route...     7.0
# 354  http://www.ladotbus.com/simple/regions/8/route...     8.0
# 505  http://www.ladotbus.com/simple/regions/7/route...     7.0
# 788  http://www.ladotbus.com/simple/regions/7/route...     7.0
#
#            regiontype  routeid                                      routename  \
# 180     Downtown Dash     29.0                                        Route F
# 916  Commuter Express     12.0                               CE549 - Pasadena
# 913    Community Dash     11.0                                     Northridge
# 354  Commuter Express     12.0                     CE431A - VA Medical Center
# 505    Community Dash     89.0                            Hollywood Clockwise
# 788    Community Dash     89.0  Lincoln Heights / Chinatown Counter-clockwise
#
#                      routenames    stopid  \
# 180                           F   91212.0
# 916            CE549 - Pasadena  391828.0
# 913                          NR  391346.0
# 354  CE431A - VA Medical Center  468986.0
# 505                          HC  303333.0
# 788                        LHCC  305781.0
#
#                                       stopname  stopnumber  \
# 180             Figueroa & Venice (Northbound)      6129.0
# 916        Burbank Blvd & Fulton Ave Westbound      3262.0
# 913          Reseda Blvd & Chase St Southbound      3014.0
# 354  Overland Ave & National Blvd (Southbound)      8921.0
# 505                        Whitley & Yucca St.      2648.0
# 788                   Broadway & Eastlake Ave.      2169.0
#
#                                                tooltip  \
# 180  Stop: Figueroa & Venice (Northbound)\nStop No:...
# 916  Stop: Burbank Blvd & Fulton Ave Westbound\nSto...
# 913  Stop: Reseda Blvd & Chase St Southbound\nStop ...
# 354  Stop: Overland Ave & National Blvd (Southbound...
# 505  Stop: Whitley & Yucca St.\nStop No: 2648\nRout...
# 788  Stop: Broadway & Eastlake Ave.\nStop No: 2169\...
#
#                         geometry
# 180  POINT (-118.27008 34.03734)
# 916  POINT (-118.42200 34.17215)
# 913  POINT (-118.53619 34.22473)
# 354  POINT (-118.41757 34.03231)
# 505  POINT (-118.33339 34.10340)
# 788  POINT (-118.20764 34.07380)

# %% [markdown]
# This looks good. Now I will try to combine it with Big Blue Bus data. I need to think about what columns does Big Blue Bus data have, how does it compare to LADOT, and what do I need from each?

# %%
#what columns does Big Blue Bus data have, how does it compare to LADOT, and what do I need from each?
#display data
BBB_stops_city.head(1)
# Out:
#     stop_id stop_code             stop_name         stop_desc  \
# 102      38      2010  AVIATION/LAX STATION  11600 UNNAMED ST
#
#                         geometry
# 102  POINT (-118.37625 33.92950)

# %% [markdown]
# For the purposes of this exercise, I really only need stop name, stop ID, and geometry.

# %% [markdown]
# Refining columns for LADOT data:

# %%
#get column names
LADOTcitystops.columns.to_list()
# Out:
# ['nla_url',
#  'region',
#  'regiontype',
#  'routeid',
#  'routename',
#  'routenames',
#  'stopid',
#  'stopname',
#  'stopnumber',
#  'tooltip',
#  'geometry']

# %%
#list columns to keep
columnstokeep = ['stopid','stopname','geometry']
#create new dataframe
LADOTcitystops1 = LADOTcitystops[columnstokeep]
#print
LADOTcitystops1
# Out:
#         stopid                                 stopname  \
# 1632  355358.0       Anaheim St & Fries Ave (Eastbound)
# 1600  354962.0       Anaheim St & Fries Ave (Westbound)
# 1599  354957.0     Anaheim St & Avalon Blvd (Westbound)
# 1633  355370.0    Avalon Blvd & Anaheim St (Northbound)
# 1634  355380.0        Avalon Blvd & Opp St (Northbound)
# ...        ...                                      ...
# 60     42384.0  Chinatown Gold Line Station (Westbound)
# 61     42387.0                           Hill & College
# 64     42392.0                  Broadway & Gin Ling Way
# 62     42388.0                      Hill & Gin Ling Way
# 63     42390.0                       Bernard & Broadway
#
#                          geometry
# 1632  POINT (-118.26526 33.77972)
# 1600  POINT (-118.26511 33.77990)
# 1599  POINT (-118.26279 33.78001)
# 1633  POINT (-118.26237 33.78030)
# 1634  POINT (-118.26256 33.78272)
# ...                           ...
# 60    POINT (-118.23595 34.06367)
# 61    POINT (-118.23858 34.06469)
# 64    POINT (-118.23686 34.06529)
# 62    POINT (-118.23805 34.06577)
# 63    POINT (-118.23612 34.06682)
#
# [2509 rows x 3 columns]

# %% [markdown]
# Refining columns for Big Blue Bus

# %%
#list columns to keep
columnstokeep1 = ['stop_id','stop_name','geometry']
#create new dataframe
BBB_stops_city1 = BBB_stops_city[columnstokeep1]
#print
BBB_stops_city1
# Out:
#     stop_id                            stop_name                     geometry
# 102      38                 AVIATION/LAX STATION  POINT (-118.37625 33.92950)
# 82      529            AVIATION NB & IMPERIAL FS  POINT (-118.37838 33.93121)
# 194     616             CENTURY EB & AVIATION NS  POINT (-118.37904 33.94538)
# 748     532             CENTURY WB & AVIATION FS  POINT (-118.37883 33.94564)
# 618    1671                   98TH EB & AVION FS  POINT (-118.38964 33.94728)
# ..      ...                                  ...                          ...
# 722    1099         BARRINGTON NB & TERRYHILL FS  POINT (-118.46819 34.05812)
# 626    1101  BARRINGTON SB & 400 BK (REC CTR) MB  POINT (-118.46861 34.06162)
# 625    1100  BARRINGTON NB & 400 BL (REC CTR) NS  POINT (-118.46847 34.06227)
# 191     140            BARRINGTON SB & SUNSET FS  POINT (-118.46966 34.06479)
# 886    1352     BARRINGTON PL NB & CHAYOTE ST NS  POINT (-118.46896 34.06587)
#
# [586 rows x 3 columns]

# %%
#rename columns to match LADOT
BBB_stops_city1 = BBB_stops_city1.rename(columns={'stop_id': 'stopid', 'stop_name': 'stopname'})
BBB_stops_city1
# Out:
#     stopid                             stopname                     geometry
# 102     38                 AVIATION/LAX STATION  POINT (-118.37625 33.92950)
# 82     529            AVIATION NB & IMPERIAL FS  POINT (-118.37838 33.93121)
# 194    616             CENTURY EB & AVIATION NS  POINT (-118.37904 33.94538)
# 748    532             CENTURY WB & AVIATION FS  POINT (-118.37883 33.94564)
# 618   1671                   98TH EB & AVION FS  POINT (-118.38964 33.94728)
# ..     ...                                  ...                          ...
# 722   1099         BARRINGTON NB & TERRYHILL FS  POINT (-118.46819 34.05812)
# 626   1101  BARRINGTON SB & 400 BK (REC CTR) MB  POINT (-118.46861 34.06162)
# 625   1100  BARRINGTON NB & 400 BL (REC CTR) NS  POINT (-118.46847 34.06227)
# 191    140            BARRINGTON SB & SUNSET FS  POINT (-118.46966 34.06479)
# 886   1352     BARRINGTON PL NB & CHAYOTE ST NS  POINT (-118.46896 34.06587)
#
# [586 rows x 3 columns]

# %% [markdown]
# Refine columns for Metro Bus Data

# %%
#list columns to keep
columnstokeep3 = ['StopNumber','StopName','geometry']
#create new dataframe
citymetrostops1 = citymetrostops[columnstokeep3]
#rename columns to match LADOT
citymetrostops1 = citymetrostops1.rename(columns={'StopNumber': 'stopid', 'StopName': 'stopname'})
#print
citymetrostops1
# Out:
#       stopid             stopname                     geometry
# 8715   14560   Shepard / Carolina  POINT (-118.29049 33.70711)
# 8263   13800    Pacific / Shepard  POINT (-118.28810 33.70719)
# 3392    5407       Pacific / 39th  POINT (-118.28778 33.70858)
# 8277   13816       Pacific / 38th  POINT (-118.28808 33.70936)
# 8276   13815       Pacific / 36th  POINT (-118.28808 33.71127)
# ...      ...                  ...                          ...
# 6471   10561    Foothill / Cobalt  POINT (-118.45191 34.32329)
# 287      451  Bledsoe / Gladstone  POINT (-118.44484 34.32341)
# 6480   10572  Bledsoe / Gladstone  POINT (-118.44478 34.32374)
# 2299    3714       Olive View UCC  POINT (-118.45306 34.32399)
# 2300    3715       Olive View UCC  POINT (-118.45309 34.32419)
#
# [7081 rows x 3 columns]

# %% [markdown]
# Last time! Now realizing I should have made this a loop.  Doing the same thing for metro rail stops.

# %%
#list columns to keep
columnstokeep4 = ['Station','StopNumber','geometry']
#create new dataframe
citymetrorailstops1 = citymetrorailstops[columnstokeep4]
#rename columns to match LADOT
citymetrorailstops1 = citymetrorailstops1.rename(columns={'StopNumber': 'stopid', 'Station': 'stopname'})
#switch order of stopid and name to match other dataframes
citymetrorailstops1 = citymetrorailstops1.iloc[:,[1,0,2]]
#display
citymetrorailstops1.head(1)
# Out:
#     stopid                              stopname                     geometry
# 10   80113  103rd Street / Watts Towers  Station  POINT (-118.24316 33.94222)

# %% [markdown]
# Finally, combining all the public transit stops into one dataframe.

# %%
#append LADOT to LA Metro bus stops
data = [LADOTcitystops1, citymetrostops1]
df7 = pd.concat(data)
#append Big Blue Bus data to new dataframe
data5 = [df7, BBB_stops_city1]
citybus_stops = pd.concat(data5)
#append metro rail data
data8 = [citybus_stops, citymetrorailstops1]
transit_stops = pd.concat(data8)
#print as check
transit_stops.head(2)
# Out:
#         stopid                            stopname  \
# 1632  355358.0  Anaheim St & Fries Ave (Eastbound)
# 1600  354962.0  Anaheim St & Fries Ave (Westbound)
#
#                          geometry
# 1632  POINT (-118.26526 33.77972)
# 1600  POINT (-118.26511 33.77990)

# %% [markdown]
# Yay! Now I have a dataframe with all the public transit stops, including their ID, name, and geometry.

# %%
#plot as check
transit_stops.plot(marker='.',markersize=1)
# Out:
# <AxesSubplot: >

# %%
#create csv from dataframe
transit_stops.to_csv('transit_stops.csv')

# %% [markdown]
# ### Create Plot Of Senior Population Density vs. Transit Stop Locations

# %%
#Pull in the senior population density dataframe from Lucy's data cleaning work.
seniors=gpd.read_file('Senior_Pop_Density.geojson')
seniors.head()
# Out:
#       BG20   ShapeSTArea          FIPS  Age 65-74  Age 75-84  Age 85+  \
# 0  2742023  1.045276e+06  060372742023          0          0       13
# 1  2739025  5.131686e+06  060372739025        120         38        0
# 2  2739024  1.861628e+06  060372739024         90         10        0
# 3  2739023  1.218168e+06  060372739023         92        137       11
# 4  2735023  4.868382e+06  060372735023         29         40        0
#
#    Total Senior Pop  Square Miles  Pop Density  \
# 0                13      0.403581         32.0
# 1               158      1.981346         80.0
# 2               100      0.718775        139.0
# 3               240      0.470335        510.0
# 4                69      1.879684         37.0
#
#                                             geometry
# 0  POLYGON ((-118.46464 33.97641, -118.46508 33.9...
# 1  MULTIPOLYGON (((-118.47291 33.98356, -118.4713...
# 2  POLYGON ((-118.46565 33.97974, -118.46587 33.9...
# 3  POLYGON ((-118.46315 33.98615, -118.46310 33.9...
# 4  POLYGON ((-118.47672 33.98746, -118.47506 33.9...

# %%
seniors.describe()
# Out:
#         ShapeSTArea    Age 65-74   Age 75-84      Age 85+  Total Senior Pop  \
# count  2.954000e+03  2954.000000  2954.00000  2954.000000       2954.000000
# mean   7.499446e+06   111.705823    52.13304    26.255586        190.094448
# std    7.053055e+07    78.536054    49.92236    36.223027        129.102721
# min    2.306666e+05     0.000000     0.00000     0.000000          0.000000
# 25%    1.777005e+06    56.000000    17.00000     0.000000        102.000000
# 50%    2.816535e+06    95.000000    40.00000    15.000000        161.000000
# 75%    4.555591e+06   149.750000    72.00000    36.000000        245.000000
# max    3.292452e+09   513.000000   516.00000   340.000000        908.000000
#
#        Square Miles  Pop Density
# count   2954.000000  2954.000000
# mean       2.895539   182.610359
# std       27.231873   187.709189
# min        0.089060     0.000000
# 25%        0.686102    81.000000
# 50%        1.087465   135.000000
# 75%        1.758915   218.750000
# max     1271.216835  2871.000000

# %%
# Now I create a "colors" column in each separate dataframe that denotes the color I want things to show up as.

seniors.loc[seniors["Pop Density"] < 135.000000, "colors"]= '#01665e' 
seniors.head(1)
# Out:
#       BG20   ShapeSTArea          FIPS  Age 65-74  Age 75-84  Age 85+  \
# 0  2742023  1.045276e+06  060372742023          0          0       13
#
#    Total Senior Pop  Square Miles  Pop Density  \
# 0                13      0.403581         32.0
#
#                                             geometry   colors
# 0  POLYGON ((-118.46464 33.97641, -118.46508 33.9...  #01665e

# %%
# I am going to have to create a manual legend since I have multiple layers, so I will first create a color dictionary.
color_dict = {'1: Below Median Senior Density': '#A23B72',
 '2: Above Median Senior Density': '#00916E',
 '3: Transit Stops': '#FFCF00'}

# Now I create a "colors" column in each separate dataframe that denotes the color I want things to show up as.

seniors.loc[seniors["Pop Density"] < 135.000000, "colors"]= '#A23B72' 
seniors.loc[seniors["Pop Density"] >= 135.000000, "colors"]= '#00916E' 
transit_stops["colors"] = '#FFCF00'

#Plot Bus Stops and Metro Stops on top of Senior Population Density
fig,ax = plt.subplots(figsize=(12,12))
ax1=seniors.plot(ax=ax,zorder=1,color=seniors['colors'])

#plot LA metro bus stops
ax2=transit_stops.plot(ax=ax, zorder=2, marker='.',markersize=1,legend=True,color=transit_stops['colors'])
                                                                                                
# Add manual legend.
from matplotlib.lines import Line2D
custom_points = [Line2D([0], [0], marker="o", linestyle="none", markersize=10, color=color) for color in color_dict.values()]
leg_points = ax.legend(custom_points, color_dict.keys(), title="Seniors per Sq. Mile and Transit Stops")
ax.add_artist(leg_points)


#Format plot.
ax.axis('off')
ax.set_title('Seniors and Public Transit Stops in the City of Los Angeles')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)
plt.savefig('seniors_transit_stops.png')

# %% [markdown]
# ### Trying to get a metric of density of transit stops/block group

# %%
#What is the best column indentifier for a block group?
cityblockgroups.head()
# Out:
#       OBJECTID     BG20    CT20 LABEL   ShapeSTArea  ShapeSTLength  \
# 2456      2457  2742023  274202  BG 3  1.045276e+06    4082.112116
# 2449      2450  2739025  273902  BG 5  5.131686e+06    9166.983856
# 2448      2449  2739024  273902  BG 4  1.861628e+06    6284.133027
# 2447      2448  2739023  273902  BG 3  1.218168e+06    4851.582209
# 2435      2436  2735023  273502  BG 3  4.868382e+06   10124.770714
#
#                                                geometry
# 2456  POLYGON ((-118.46464 33.97641, -118.46508 33.9...
# 2449  MULTIPOLYGON (((-118.47291 33.98356, -118.4713...
# 2448  POLYGON ((-118.46565 33.97974, -118.46587 33.9...
# 2447  POLYGON ((-118.46315 33.98615, -118.46310 33.9...
# 2435  POLYGON ((-118.47672 33.98746, -118.47506 33.9...

# %% [markdown]
# I will use "BG20" as my block group unique identifier.

# %%
#join transit data with cityblockgroup data
transit_bg = gpd.sjoin(cityblockgroups,transit_stops)
#display
transit_bg.sample(3)
# Out:
#       OBJECTID     BG20    CT20 LABEL   ShapeSTArea  ShapeSTLength  \
# 1814      1815  2260021  226002  BG 1  1.229651e+07   16230.136828
# 2216      2217  2627041  262704  BG 1  6.604831e+06   13133.362319
# 923        924  1434013  143401  BG 3  3.860083e+06    9814.281358
#
#                                                geometry  index_right   stopid  \
# 1814  POLYGON ((-118.25218 34.02739, -118.25271 34.0...          153  90982.0
# 2216  POLYGON ((-118.52945 34.04816, -118.52945 34.0...         4039   6412.0
# 923   POLYGON ((-118.41379 34.15399, -118.41498 34.1...        11009  18221.0
#
#                             stopname   colors
# 1814  Los Angeles & 9th (Northbound)  #FFCF00
# 2216              Sunset / Muskingum  #FFCF00
# 923         Coldwater Canyon / Sarah  #FFCF00

# %% [markdown]
# I will use value counts to get the number of unique stops per block group.

# %%
#Use valuecounts to get the number of unique stops per block group
transit_bg_count= transit_bg.value_counts(['BG20']).reset_index(name='stop_count')
#display
transit_bg_count.head()
# Out:
#       BG20  stop_count
# 0  2074001         177
# 1  2077122          79
# 2  2079021          67
# 3  2240201          53
# 4  2077111          49

# %% [markdown]
# Now I have a dataframe that has the number of transit stops per block group.

# %%
#Basic statistics on the number of transit stops/block group
transit_bg_count.describe()
# Out:
#         stop_count
# count  2274.000000
# mean      4.500000
# std       6.000165
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       5.000000
# max     177.000000

# %%
#rename column for plotting
transit_bg_count.rename(columns={'stop_count': 'Number of Transit Stops Per Block Group'}, inplace=True)
#plot a histogram
transit_bg_count.hist(bins=10)
# Out:
# array([[<AxesSubplot: title={'center': 'Number of Transit Stops Per Block Group'}>]],
#       dtype=object)

# %% [markdown]
# What block group has 177 stops? Is that accurate?

# %%
#change name of column back 
transit_bg_count.rename(columns={'Number of Transit Stops Per Block Group': 'stop_count'}, inplace=True)
#find the block group ID where # of stops = 177(max)
transit_bg_count.loc[transit_bg_count['stop_count'] == 177]
# Out:
#       BG20  stop_count
# 0  2074001         177

# %%
#find the geography of that block group
some_values = ['2074001']
maxbg = transit_bg.loc[transit_bg['BG20'].isin(some_values)]
maxbg.head(1)
# Out:
#       OBJECTID     BG20    CT20 LABEL   ShapeSTArea  ShapeSTLength  \
# 1424      1425  2074001  207400  BG 1  9.358166e+06    15170.87179
#
#                                                geometry  index_right   stopid  \
# 1424  POLYGON ((-118.23805 34.05107, -118.23971 34.0...         6424  10493.0
#
#                    stopname   colors
# 1424  1st / Judge John Aiso  #FFCF00

# %%
#Plot the block group with context as check
fig,ax = plt.subplots(figsize=(6,6))
ax1=maxbg.plot(ax=ax)

#Format plot.
ax.axis('off')
ax.set_title('Block Group with Highest Number of Transit Stops')
ctx.add_basemap(ax, crs=4326)

# %% [markdown]
# This is right in downtown Los Angeles, so it does make sense as the block group with the most transit stops.

# %% [markdown]
# I want to add transit_bg_count back to my larger dataframe so that I have the spatial data included.

# %%
#Join transit_bg_count with ciytblockgroups
transit_bg_count_new = transit_bg_count.merge(cityblockgroups, on='BG20',how='left')

# %%
#print sample
transit_bg_count_new.sample(2)
# Out:
#          BG20  stop_count  OBJECTID    CT20 LABEL   ShapeSTArea  \
# 2108  2015014           1      1328  201501  BG 4  3.144367e+06
# 1939  1047013           1        82  104701  BG 3  1.521330e+06
#
#       ShapeSTLength                                           geometry
# 2108    8435.316264  POLYGON ((-118.16652 34.08102, -118.16710 34.0...
# 1939    4994.961295  POLYGON ((-118.41875 34.26327, -118.41929 34.2...

# %%
#change ShapeStArea datatype to int
transit_bg_count_new['ShapeSTArea'] = transit_bg_count_new['ShapeSTArea'].astype('int')
#create column for density of transit stops
transit_bg_count_new['stopdensity'] = transit_bg_count_new['ShapeSTArea']/transit_bg_count_new['stop_count']
#print as check
transit_bg_count_new.head(2)
# Out:
#       BG20  stop_count  OBJECTID    CT20 LABEL  ShapeSTArea  ShapeSTLength  \
# 0  2074001         177      1425  207400  BG 1      9358165   15170.871790
# 1  2077122          79      1432  207712  BG 2      2738696    6782.687349
#
#                                             geometry   stopdensity
# 0  POLYGON ((-118.23805 34.05107, -118.23971 34.0...  52870.988701
# 1  POLYGON ((-118.25446 34.04591, -118.25500 34.0...  34667.037975

# %%
#check for null values
transit_bg_count_new['stopdensity'].isnull().values.any()
# Out:
# False

# %%
transit_bg_count_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2274 entries, 0 to 2273
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BG20           2274 non-null   object
#  1   stop_count     2274 non-null   int64
#  2   OBJECTID       2274 non-null   int64
#  3   CT20           2274 non-null   object
#  4   LABEL          2274 non-null   object
#  5   ShapeSTArea    2274 non-null   int64
#  6   ShapeSTLength  2274 non-null   float64
#  7   geometry       2274 non-null   geometry
#  8   stopdensity    2274 non-null   float64
# dtypes: float64(2), geometry(1), int64(3), object(3)
# memory usage: 177.7+ KB

# %%
#change density datatype to int
transit_bg_count_new['stopdensity'] = transit_bg_count_new['stopdensity'].astype('int')

# %%
#Basic statistics on the density of transit stops/block group
transit_bg_count_new.describe()
# Out:
#         stop_count     OBJECTID   ShapeSTArea  ShapeSTLength   stopdensity
# count  2274.000000  2274.000000  2.274000e+03    2274.000000  2.274000e+03
# mean      4.500000  1363.575638  4.707169e+06    8998.465135  1.687712e+06
# std       6.000165   861.885992  1.474003e+07    6918.626498  1.041414e+07
# min       1.000000     2.000000  2.306660e+05    2059.690684  2.819300e+04
# 25%       2.000000   682.250000  1.752579e+06    5839.678273  4.862285e+05
# 50%       3.000000  1355.500000  2.667465e+06    7469.002372  8.676690e+05
# 75%       5.000000  1964.750000  4.202385e+06    9741.448554  1.516737e+06
# max     177.000000  6587.000000  4.761975e+08  155767.638460  4.761975e+08

# %%
transit_bg_count_new.to_csv('transit_stopcount.csv')

# %% [markdown]
# Now I want to create some charts to look at stop density across block groups. I will start by making a column that indicates which block groups are below the average stop density (mean stop density = 1.687713e+06)

# %%
#creating a list to look at average stop density
avgstopdensity = []
for row in transit_bg_count_new['stopdensity']:
        if row < 1.687713e+06:    avgstopdensity.append('below_mean')
        elif row > 1.687713e+06:   avgstopdensity.append('above_mean')
        
        else:          avgstopdensity.append('NaN')

# %%
#how many block groups have below average stop density?
avgstopdensity.count('below_mean')
# Out:
# 1782

# %% [markdown]
# 1782 block groups have below average transit stop density - that is too many to look at, so I am going to look at percentiles instead.

# %%
#creating a list to look at percentiles of stop density
perstopdensity = []
for row in transit_bg_count_new['stopdensity']:
        if row < 4.862288e+05:    perstopdensity.append(25)
        elif row > 8.676696e+05:   perstopdensity.append(50)
        elif row > 1.516737e+06:   perstopdensity.append(75)
        elif row > 4.761975e+08:   perstopdensity.append(100)
        
        else:          perstopdensity.append('NaN')

# %%
#how many block groups are in the top 25% of stop density?
perstopdensity.count(25)
# Out:
# 569

# %% [markdown]
# This is more useable, I will go with the bottom quartile for my analysis.

# %% [markdown]
# First I will get only the subsets of the dataframe in the top and bottom 25%.

# %%
#subsetting the dataframe for top 25%
top25 = transit_bg_count_new[transit_bg_count_new["stopdensity"] < 4.862288e+05]
top25.head(3)
# Out:
#       BG20  stop_count  OBJECTID    CT20 LABEL  ShapeSTArea  ShapeSTLength  \
# 0  2074001         177      1425  207400  BG 1      9358165   15170.871790
# 1  2077122          79      1432  207712  BG 2      2738696    6782.687349
# 2  2079021          67      1435  207902  BG 1      6744683   11059.851331
#
#                                             geometry  stopdensity
# 0  POLYGON ((-118.23805 34.05107, -118.23971 34.0...        52870
# 1  POLYGON ((-118.25446 34.04591, -118.25500 34.0...        34667
# 2  POLYGON ((-118.25723 34.03457, -118.25828 34.0...       100666

# %% [markdown]
# Now I have a dataframe of only the bottom 25% of transit stop density blockgroups.

# %%
#Get the BG20 identifiers from this datframe as a series.
highdensityBG = top25['BG20']
#get info
highdensityBG.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 569 entries, 0 to 2081
# Series name: BG20
# Non-Null Count  Dtype
# --------------  -----
# 569 non-null    object
# dtypes: object(1)
# memory usage: 8.9+ KB

# %%
#create dataframe of spatial data of bottom 25% transit density block groups. 
highdensityBGdf = transit_bg.loc[transit_bg['BG20'].isin(highdensityBG)]
#print
highdensityBGdf.head(1)
# Out:
#       OBJECTID     BG20    CT20 LABEL   ShapeSTArea  ShapeSTLength  \
# 2456      2457  2742023  274202  BG 3  1.045276e+06    4082.112116
#
#                                                geometry  index_right   stopid  \
# 2456  POLYGON ((-118.46464 33.97641, -118.46508 33.9...         7618  12686.0
#
#                  stopname   colors
# 2456  Pacific / Driftwood  #FFCF00

# %% [markdown]
# I'm going to repeat this process for the low density tranit block groups.

# %%
low25 = transit_bg_count_new[transit_bg_count_new["stopdensity"] > 1.516737e+06]
low25.head(3)
# Out:
#        BG20  stop_count  OBJECTID    CT20 LABEL  ShapeSTArea  ShapeSTLength  \
# 5   9800281          45      6579  980028  BG 1    211924310   85718.579965
# 17  9800241          27      6576  980024  BG 1     89196152   46246.894948
# 40  9800091          18      6561  980009  BG 1    228869386   81127.024463
#
#                                              geometry  stopdensity
# 5   POLYGON ((-118.44701 33.95176, -118.44656 33.9...      4709429
# 17  POLYGON ((-118.46955 34.17926, -118.46917 34.1...      3303561
# 40  POLYGON ((-118.30627 34.16024, -118.30504 34.1...     12714965

# %%
#Get the BG20 identifiers from this datframe as a series.
lowdensityBG = low25['BG20']
#print
lowdensityBG
# Out:
# 5       9800281
# 17      9800241
# 40      9800091
# 41      1133032
# 50      9800081
#          ...
# 2269    1241041
# 2270    1241023
# 2271    2324021
# 2272    2324022
# 2273    9800381
# Name: BG20, Length: 569, dtype: object

# %%
#create dataframe of spatial data of top 25% transit density block groups. 
lowdensityBGdf = transit_bg.loc[transit_bg['BG20'].isin(lowdensityBG)]
#print
lowdensityBGdf.head(1)
# Out:
#       OBJECTID     BG20    CT20 LABEL   ShapeSTArea  ShapeSTLength  \
# 2448      2449  2739024  273902  BG 4  1.861628e+06    6284.133027
#
#                                                geometry  index_right  \
# 2448  POLYGON ((-118.46565 33.97974, -118.46587 33.9...          599
#
#         stopid                                  stopname   colors
# 2448  424404.0  Pacific Ave & Washington Blvd (Arriving)  #FFCF00

# %% [markdown]
# Now, I will use this to create plots of the lower and higher transit stop density areas.

# %%
#Plot the low density transit stop block groups with context
fig,ax = plt.subplots(figsize=(6,6))
ax1=lowdensityBGdf.plot(ax=ax, color='darkcyan')

#Format plot.
ax.axis('off')
ax.set_title('Block Groups in Lowest Quartile of Transit Stop Density')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)
plt.savefig('low25transitdensity.png')

# %%
#Plot the high density transit stop block groups with context
fig,ax = plt.subplots(figsize=(6,6))
ax1=highdensityBGdf.plot(ax=ax, color='darkcyan')

#Format plot.
ax.axis('off')
ax.set_title('Block Groups in Highest Quartile of Transit Stop Density')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)
plt.savefig('top25transitdensity.png')

# %% [markdown]
# #### Part 2: Identifying Block Groups with Walking Access to Transit Stops

# %% [markdown]
# In this section I will be following Monisha's steps to create buffers and identify which block groups are within/touching these buffers.
#
# Create various walking distance buffers around all transit stops
# Determine which census blocks are within these buffers.
# Since the walking distance calculations will be based in meters, I'll first have to convert the CRS of all geodataframes to EPSG 6423, which is the meter-based CRS for Los Angeles County.

# %%
#drop NaN values form transit_stops
transit_stops.dropna(inplace=True)

# Create a new geodataframe of chain locations that is in a projection that accurately calculates things in meters.
transit_projection=transit_stops.to_crs('epsg:6423')

# Read the geojson file that Lucy created this week to get data on census block group demographics.
seniors=gpd.read_file('Percent_Senior_Basemap.geojson')

# Create a new geodataframe of blok groups that is in a projection that accurately calculates things in meters.
seniors_projection=seniors.to_crs('epsg:6423')

# %% [markdown]
# Now, I create a short walking distance buffer around the transit stops: 1/4 mile and 1/8 mile. For grocery stores we also considered 1/2 mile, but considering you have to walk after getting off another stop that could end up being a lot of mileage for folks using transit.

# %%
# Create a new geodataframe that will contain my 1/4 mile buffers. 
transit_buffer_025=transit_projection

# Add a new column (walkshed) that contains a 402.336 meter (1/4 mile) buffer around each point. 
transit_buffer_025['walkshed'] = transit_buffer_025.buffer(402.336)

# Make my new buffer column the primary geometry for the geodataframe. 
transit_buffer_025=transit_buffer_025.set_geometry('walkshed')

# %%
# Create a new geodataframe that will contain my 1/8 mile buffers. 
transit_buffer_0125=transit_projection

# Add a new column (walkshed) that contains a 1/8 mile buffer around each point. 
transit_buffer_0125['walkshed'] = transit_buffer_0125.buffer(201.168)

# Make my new buffer column the primary geometry for the geodataframe. 
transit_buffer_0125=transit_buffer_0125.set_geometry('walkshed')

# %% [markdown]
# Map the buffers to enure it worked.

# %%
# I am going to have to create a manual legend since I have multiple layers, so I will first create a color dictionary.
color_dict = {'1: No walkable transit stop': '#a6611a',
 '2: Transit stop within 1/4 mile': '#80cdc1',
 '3: Transit stop within 1/8 mile': '#01665e'}

# Now I create a "colors" column in each separate dataframe that denotes the color I want things to show up as.
transit_buffer_0125["colors"] = '#01665e'
transit_buffer_025["colors"] = '#80cdc1'
seniors_projection["colors"] = '#a6611a'

# Now I create my actual map with the three geodataframes added in the appropriate order (zorder).
fig,ax = plt.subplots(figsize=(12,12))
transit_buffer_0125.plot(ax=ax, zorder=3, color=transit_buffer_0125['colors'])
transit_buffer_025.plot(ax=ax, zorder=2, color=transit_buffer_025['colors'])
seniors_projection.plot(ax=ax, zorder=1, color=seniors_projection['colors'])

# Add manual legend.
from matplotlib.lines import Line2D
custom_points = [Line2D([0], [0], marker="o", linestyle="none", markersize=10, color=color) for color in color_dict.values()]
leg_points = ax.legend(custom_points, color_dict.keys(), title="Access to Transit Stop")
ax.add_artist(leg_points)

#Format plot axis, title, and basemap.
ax.axis('off')
ax.set_title('Walksheds Around Transit Stops in the City of Los Angeles')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs='epsg:6423')

plt.savefig('transitbuffers.png')

# %% [markdown]
# I like this map, and will use it for the midterm.  I will continue this analysis for the final.

# %% [markdown]
# ## Notes on Midterm Division of Labor:
#
# Monisha focused on grocery stores, creating an interactive map as well as many other impressive maps showing walkable areas around grocery stores. She developed the methodology for the buffer/walkshed process.
#
# Lucy focused on census data, creating charts and basemaps of the density of seniors across LA compared to the general population.
#
# Adriana focused on car access, creating a chart looking at car access among seniors compared to other age groups. She also designed/organized our slide deck.
#
# This notebook represents my contributions, mostly focused on maps related to transit density.  Notably, we all helped each other out and I borrowed may of these ideas/methods from my teammates.
