# %% [markdown]
# # Midterm: Snake Emoji
# ## Research Question: Where do gaps in transit access to grocery stores exist for residents ages 65+ in the city of Los Angeles?
# Group Members: Adriana Ochoa, Carolyn Pugh, Monisha Reginald, Lucy Briggs
#
# For my segment of this midterm, I will be creating maps of the population density of residents age 65 and up by block group within the City of LA. I will be using age data from the [American Community Survey](https://www.socialexplorer.com/reports/socialexplorer/en/report/0cc0f56c-9d1c-11ed-be9e-e30303f780e8), Census Block Group Boundaries from [LA City GeoHub](https://geohub.lacity.org/datasets/lacounty::census-block-groups-2020/about), and the City of Los Angeles Boundary from [LA City GeoHub](https://geohub.lacity.org/datasets/city-boundary/explore?location=34.019779%2C-118.412043%2C10.96).

# %% [markdown]
# This week I will work on finalizing the basemaps for our midterm presentation. Additionally, I will attempt to create some charts for presentation.

# %% [markdown]
# # Part 1: Create a Normalized Map of Age 65+ Population by Block Group
#
# Although we have a map of the density of seniors by block group, we want to normalize this data over the entire population so we can see what percentage of each block group is Seniors.

# %%
#libraries
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import fiona 
import numpy as np
import math

# %% [markdown]
# ## Importing age data
# From here, we want a normalized age data table with percent seniors/ total population. Let's start with some data exporlation.

# %%
df = pd.read_csv('age.csv')
df.head(5)
df.columns
# Out:
# Index(['Geo_FIPS', 'Geo_QName', 'Geo_FILEID', 'Geo_STUSAB', 'Geo_SUMLEV',
#        'Geo_GEOCOMP', 'Geo_LOGRECNO', 'Geo_US', 'Geo_REGION', 'Geo_DIVISION',
#        'Geo_STATECE', 'Geo_STATE', 'Geo_COUNTY', 'Geo_COUSUB', 'Geo_PLACE',
#        'Geo_TRACT', 'Geo_BLKGRP', 'Geo_CONCIT', 'Geo_AIANHH', 'Geo_AIANHHFP',
#        'Geo_AIHHTLI', 'Geo_AITSCE', 'Geo_AITS', 'Geo_ANRC', 'Geo_CBSA',
#        'Geo_CSA', 'Geo_METDIV', 'Geo_MACC', 'Geo_MEMI', 'Geo_NECTA',
#        'Geo_CNECTA', 'Geo_NECTADIV', 'Geo_UA', 'Geo_UACP', 'Geo_CDCURR',
#        'Geo_SLDU', 'Geo_SLDL', 'Geo_VTD', 'Geo_ZCTA3', 'Geo_ZCTA5',
#        'Geo_SUBMCD', 'Geo_SDELM', 'Geo_SDSEC', 'Geo_SDUNI', 'Geo_UR',
#        'Geo_PCI', 'Geo_TAZ', 'Geo_UGA', 'Geo_PUMA5', 'Geo_PUMA1', 'Geo_GEOID',
#        'Geo_NAME', 'Geo_BTTR', 'Geo_BTBG', 'Geo_PLACESE', 'SE_A01001_001',
#        'SE_A01001_002', 'SE_A01001_003', 'SE_A01001_004', 'SE_A01001_005',
#        'SE_A01001_006', 'SE_A01001_007', 'SE_A01001_008', 'SE_A01001_009',
#        'SE_A01001_010', 'SE_A01001_011', 'SE_A01001_012', 'SE_A01001_013'],
#       dtype='object')

# %% [markdown]
# The "Total Population" Column is 'SE_A01001_001' According to the [data dictionary](https://www.socialexplorer.com/data/ACS2021_5yr/metadata/?ds=SE)

# %% [markdown]
# # Fixing Geo_FIPS leading zero
#
# This will allow us to join the data with the spatial block boundaries using a primary key.

# %%
df.Geo_FIPS.head()
# Out:
# 0    60014001001
# 1    60014001002
# 2    60014002001
# 3    60014002002
# 4    60014003001
# Name: Geo_FIPS, dtype: int64

# %% [markdown]
# Specify that Geo FIPS is a string so it doesn't drop the leading zero

# %%
#specify geofips as a string
df = pd.read_csv('age.csv',
                 dtype = 
                 {
                     'Geo_FIPS':str,
                     'Geo_STATE':str, 
                     'Geo_COUNTY':str
                 }
                )

# %%
df.head(5)
# Out:
#        Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  060014001001  Block Group 1, Census Tract 4001, Alameda Coun...      ACSSF
# 1  060014001002  Block Group 2, Census Tract 4001, Alameda Coun...      ACSSF
# 2  060014002001  Block Group 1, Census Tract 4002, Alameda Coun...      ACSSF
# 3  060014002002  Block Group 2, Census Tract 4002, Alameda Coun...      ACSSF
# 4  060014003001  Block Group 1, Census Tract 4003, Alameda Coun...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 0         ca         150            0         11947     NaN         NaN
# 1         ca         150            0         11948     NaN         NaN
# 2         ca         150            0         11949     NaN         NaN
# 3         ca         150            0         11950     NaN         NaN
# 4         ca         150            0         11951     NaN         NaN
#
#    Geo_DIVISION  ...  SE_A01001_004 SE_A01001_005 SE_A01001_006  \
# 0           NaN  ...            243            57            98
# 1           NaN  ...             29            19            14
# 2           NaN  ...             52            32            31
# 3           NaN  ...             38            22            30
# 4           NaN  ...             41            37            39
#
#    SE_A01001_007  SE_A01001_008  SE_A01001_009  SE_A01001_010  SE_A01001_011  \
# 0            221            111            395            228            214
# 1            121            186            139            311            226
# 2            115            125            117            123            232
# 3            310            155            111             91             62
# 4            225            147            173            137            141
#
#    SE_A01001_012  SE_A01001_013
# 0            116             67
# 1             95             83
# 2             70             17
# 3             82             11
# 4             67              0
#
# [5 rows x 68 columns]

# %%
#confirming it changed to a string
df.info(verbose = True, show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25607 entries, 0 to 25606
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       25607 non-null  object
#  1   Geo_QName      25607 non-null  object
#  2   Geo_FILEID     25607 non-null  object
#  3   Geo_STUSAB     25607 non-null  object
#  4   Geo_SUMLEV     25607 non-null  int64
#  5   Geo_GEOCOMP    25607 non-null  int64
#  6   Geo_LOGRECNO   25607 non-null  int64
#  7   Geo_US         0 non-null      float64
#  8   Geo_REGION     0 non-null      float64
#  9   Geo_DIVISION   0 non-null      float64
#  10  Geo_STATECE    0 non-null      float64
#  11  Geo_STATE      25607 non-null  object
#  12  Geo_COUNTY     25607 non-null  object
#  13  Geo_COUSUB     0 non-null      float64
#  14  Geo_PLACE      0 non-null      float64
#  15  Geo_TRACT      25607 non-null  int64
#  16  Geo_BLKGRP     25607 non-null  int64
#  17  Geo_CONCIT     0 non-null      float64
#  18  Geo_AIANHH     0 non-null      float64
#  19  Geo_AIANHHFP   0 non-null      float64
#  20  Geo_AIHHTLI    0 non-null      float64
#  21  Geo_AITSCE     0 non-null      float64
#  22  Geo_AITS       0 non-null      float64
#  23  Geo_ANRC       0 non-null      float64
#  24  Geo_CBSA       0 non-null      float64
#  25  Geo_CSA        0 non-null      float64
#  26  Geo_METDIV     0 non-null      float64
#  27  Geo_MACC       0 non-null      float64
#  28  Geo_MEMI       0 non-null      float64
#  29  Geo_NECTA      0 non-null      float64
#  30  Geo_CNECTA     0 non-null      float64
#  31  Geo_NECTADIV   0 non-null      float64
#  32  Geo_UA         0 non-null      float64
#  33  Geo_UACP       0 non-null      float64
#  34  Geo_CDCURR     0 non-null      float64
#  35  Geo_SLDU       0 non-null      float64
#  36  Geo_SLDL       0 non-null      float64
#  37  Geo_VTD        0 non-null      float64
#  38  Geo_ZCTA3      0 non-null      float64
#  39  Geo_ZCTA5      0 non-null      float64
#  40  Geo_SUBMCD     0 non-null      float64
#  41  Geo_SDELM      0 non-null      float64
#  42  Geo_SDSEC      0 non-null      float64
#  43  Geo_SDUNI      0 non-null      float64
#  44  Geo_UR         0 non-null      float64
#  45  Geo_PCI        0 non-null      float64
#  46  Geo_TAZ        0 non-null      float64
#  47  Geo_UGA        0 non-null      float64
#  48  Geo_PUMA5      0 non-null      float64
#  49  Geo_PUMA1      0 non-null      float64
#  50  Geo_GEOID      25607 non-null  object
#  51  Geo_NAME       25607 non-null  object
#  52  Geo_BTTR       0 non-null      float64
#  53  Geo_BTBG       0 non-null      float64
#  54  Geo_PLACESE    0 non-null      float64
#  55  SE_A01001_001  25607 non-null  int64
#  56  SE_A01001_002  25607 non-null  int64
#  57  SE_A01001_003  25607 non-null  int64
#  58  SE_A01001_004  25607 non-null  int64
#  59  SE_A01001_005  25607 non-null  int64
#  60  SE_A01001_006  25607 non-null  int64
#  61  SE_A01001_007  25607 non-null  int64
#  62  SE_A01001_008  25607 non-null  int64
#  63  SE_A01001_009  25607 non-null  int64
#  64  SE_A01001_010  25607 non-null  int64
#  65  SE_A01001_011  25607 non-null  int64
#  66  SE_A01001_012  25607 non-null  int64
#  67  SE_A01001_013  25607 non-null  int64
# dtypes: float64(42), int64(18), object(8)
# memory usage: 13.3+ MB

# %% [markdown]
# The leading zero is there, so we won't run in to issues when joining.

# %% [markdown]
# # Deleting Null Columns

# %% [markdown]
# There are plenty of null columns that we don't need for this analysis.

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_PUMA5',
#  'Geo_PUMA1',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE']

# %%
df = df.dropna(axis=1,how='all')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25607 entries, 0 to 25606
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       25607 non-null  object
#  1   Geo_QName      25607 non-null  object
#  2   Geo_FILEID     25607 non-null  object
#  3   Geo_STUSAB     25607 non-null  object
#  4   Geo_SUMLEV     25607 non-null  int64
#  5   Geo_GEOCOMP    25607 non-null  int64
#  6   Geo_LOGRECNO   25607 non-null  int64
#  7   Geo_STATE      25607 non-null  object
#  8   Geo_COUNTY     25607 non-null  object
#  9   Geo_TRACT      25607 non-null  int64
#  10  Geo_BLKGRP     25607 non-null  int64
#  11  Geo_GEOID      25607 non-null  object
#  12  Geo_NAME       25607 non-null  object
#  13  SE_A01001_001  25607 non-null  int64
#  14  SE_A01001_002  25607 non-null  int64
#  15  SE_A01001_003  25607 non-null  int64
#  16  SE_A01001_004  25607 non-null  int64
#  17  SE_A01001_005  25607 non-null  int64
#  18  SE_A01001_006  25607 non-null  int64
#  19  SE_A01001_007  25607 non-null  int64
#  20  SE_A01001_008  25607 non-null  int64
#  21  SE_A01001_009  25607 non-null  int64
#  22  SE_A01001_010  25607 non-null  int64
#  23  SE_A01001_011  25607 non-null  int64
#  24  SE_A01001_012  25607 non-null  int64
#  25  SE_A01001_013  25607 non-null  int64
# dtypes: int64(18), object(8)
# memory usage: 5.1+ MB

# %% [markdown]
# We dropped a lot of null columns. We still have 25 non-null columns, most relate to age group.

# %% [markdown]
# # Create a "Total Senior Populaton" Column
# We want a column of "totals" that is a sum of columns ending in 011, 012, and 013, because these represent the age groups (65+) that we are concerned with.

# %%
df['Total Senior Pop']=df.iloc[:,[23,24,25]].sum(axis=1)

# %%
df.head(5)
# Out:
#        Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  060014001001  Block Group 1, Census Tract 4001, Alameda Coun...      ACSSF
# 1  060014001002  Block Group 2, Census Tract 4001, Alameda Coun...      ACSSF
# 2  060014002001  Block Group 1, Census Tract 4002, Alameda Coun...      ACSSF
# 3  060014002002  Block Group 2, Census Tract 4002, Alameda Coun...      ACSSF
# 4  060014003001  Block Group 1, Census Tract 4003, Alameda Coun...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO Geo_STATE Geo_COUNTY  \
# 0         ca         150            0         11947        06        001
# 1         ca         150            0         11948        06        001
# 2         ca         150            0         11949        06        001
# 3         ca         150            0         11950        06        001
# 4         ca         150            0         11951        06        001
#
#    Geo_TRACT  ...  SE_A01001_005 SE_A01001_006 SE_A01001_007  SE_A01001_008  \
# 0     400100  ...             57            98           221            111
# 1     400100  ...             19            14           121            186
# 2     400200  ...             32            31           115            125
# 3     400200  ...             22            30           310            155
# 4     400300  ...             37            39           225            147
#
#    SE_A01001_009  SE_A01001_010  SE_A01001_011  SE_A01001_012  SE_A01001_013  \
# 0            395            228            214            116             67
# 1            139            311            226             95             83
# 2            117            123            232             70             17
# 3            111             91             62             82             11
# 4            173            137            141             67              0
#
#    Total Senior Pop
# 0               397
# 1               404
# 2               319
# 3               155
# 4               208
#
# [5 rows x 27 columns]

# %% [markdown]
# Now we have a column showing the total number of resdents age 65+.

# %% [markdown]
# # Which columns to keep?
# Look at data dictionary and figure out which columns to keep.

# %% [markdown]
# link to data dictionary: https://www.socialexplorer.com/data/ACS2021_5yr/metadata/?ds=SE
#
# Only keep FIPS, Total Population, and the age groups we are interested in (65+), as well as the Total Senior Population column that we created.

# %%
columns_to_keep = ['Geo_FIPS',
                   'SE_A01001_001',     
                   'SE_A01001_011',
                   'SE_A01001_012',
                   'SE_A01001_013',
                  'Total Senior Pop']
#save in a new dataframe
df2 = df[columns_to_keep]
df2.head()
# Out:
#        Geo_FIPS  SE_A01001_001  SE_A01001_011  SE_A01001_012  SE_A01001_013  \
# 0  060014001001           1963            214            116             67
# 1  060014001002           1361            226             95             83
# 2  060014002001           1029            232             70             17
# 3  060014002002           1009             62             82             11
# 4  060014003001           1122            141             67              0
#
#    Total Senior Pop
# 0               397
# 1               404
# 2               319
# 3               155
# 4               208

# %% [markdown]
# Now we have a table showing the total population of the senior groups we are interested in, as well as the total general population of each block group. This can be used to normalize the senior population data and allow us to look at percentages of seniors for each block group.

# %% [markdown]
# # Renaming Columns
# Rename the columns for easier reading

# %%
columns = list(df2)
columns
# Out:
# ['Geo_FIPS',
#  'SE_A01001_001',
#  'SE_A01001_011',
#  'SE_A01001_012',
#  'SE_A01001_013',
#  'Total Senior Pop']

# %%
#copy and paste list above, replace vals with desired names
df2.columns = ['FIPS',
               'Total Pop',
               'Age 65-74',
               'Age 75-84', 
               'Age 85+', 
               'Total Senior Pop']
df2.sample(5)
# Out:
#                FIPS  Total Pop  Age 65-74  Age 75-84  Age 85+  \
# 15855  060670075014       1566        178         78       82
# 21245  060816042002        888          1         32        9
# 8813   060375512012       2581        363         31       90
# 21369  060816080232       1674        243        180       10
# 4451   060371235101       2419         81         68       69
#
#        Total Senior Pop
# 15855               338
# 21245                42
# 8813                484
# 21369               433
# 4451                218

# %% [markdown]
# # Creating a "Percentage Seniors" Column
#
# For mapping, we want our data to be normalized across the entire population, so that increased density of seniors doesn't just reflect density as a whole population. To do this, we want to find the "rate" of senior population, so we will use the formula pct seniors = 100(senior pop/total pop).

# %%
df2['Pct Seniors'] = 100*(df2['Total Senior Pop']/df2['Total Pop']).fillna(0)
df2.sort_values('Pct Seniors', inplace=True, ascending=False)
df2.head(10)
# Out:
# /tmp/ipykernel_1402/2307236421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Pct Seniors'] = 100*(df2['Total Senior Pop']/df2['Total Pop']).fillna(0)
# /tmp/ipykernel_1402/2307236421.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.sort_values('Pct Seniors', inplace=True, ascending=False)
#                FIPS  Total Pop  Age 65-74  Age 75-84  Age 85+  \
# 20399  060759805011        104          5         63       36
# 10559  060379800331         13         13          0        0
# 10409  060379200311         18         18          0        0
# 467    060014251012         13          0         13        0
# 23907  060971524021        311         39        122      148
# 16377  060690006024         47         10         13       23
# 1852   060133511041        539        242        175      108
# 19181  060730176013       1284         54        550      645
# 15272  060650514013        928        304        594        0
# 15270  060650514011       1283        623        496      117
#
#        Total Senior Pop  Pct Seniors
# 20399               104   100.000000
# 10559                13   100.000000
# 10409                18   100.000000
# 467                  13   100.000000
# 23907               309    99.356913
# 16377                46    97.872340
# 1852                525    97.402597
# 19181              1249    97.274143
# 15272               898    96.767241
# 15270              1236    96.336711

# %% [markdown]
# Now we can see that several block groups are made up of 100% seniors. Let's see if all of these are actually within the City of LA or just the County.

# %% [markdown]
# # Clipping

# %%
import geopandas as gpd

# %% [markdown]
# We want to clip the County boundaries down to just the City of LA. First, read a dataset of all the municipalities within LA county.

# %%
cities=gpd.read_file('bg_geometries.geojson')
cities.head(5)
# Out:
#       BG20  Total_Pop  pop_density  official_area     neighborhood  \
# 0  9800391        0.0     0.000000       0.016862      Toluca Lake
# 1  9800311     1160.0   213.004200       5.445902        San Pedro
# 2  9800281        0.0     0.000000       6.679460      Westchester
# 3  9800261       16.0     2.988672       5.353549          Tujunga
# 4  9800241      200.0    64.759080       3.088370  Sepulveda Basin
#
#                                             geometry
# 0  MULTIPOLYGON (((1966685.678 571125.893, 196670...
# 1  POLYGON ((1973083.310 528189.940, 1973083.328 ...
# 2  POLYGON ((1958524.051 550029.553, 1958525.458 ...
# 3  POLYGON ((1967614.398 586716.846, 1967615.058 ...
# 4  POLYGON ((1952205.353 576098.621, 1952205.387 ...

# %% [markdown]
# Greate a BG20 column in my df

# %%
df2.head()
# Out:
#                FIPS  Total Pop  Age 65-74  Age 75-84  Age 85+  \
# 20399  060759805011        104          5         63       36
# 10559  060379800331         13         13          0        0
# 10409  060379200311         18         18          0        0
# 467    060014251012         13          0         13        0
# 23907  060971524021        311         39        122      148
#
#        Total Senior Pop  Pct Seniors
# 20399               104   100.000000
# 10559                13   100.000000
# 10409                18   100.000000
# 467                  13   100.000000
# 23907               309    99.356913

# %%
df2['BG20'] = df2['FIPS'].str[-7:].astype(int)
df2.dtypes
# Out:
# /tmp/ipykernel_1402/4101551113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['BG20'] = df2['FIPS'].str[-7:].astype(int)
# FIPS                 object
# Total Pop             int64
# Age 65-74             int64
# Age 75-84             int64
# Age 85+               int64
# Total Senior Pop      int64
# Pct Seniors         float64
# BG20                  int64
# dtype: object

# %%
df2.head()
# Out:
#                FIPS  Total Pop  Age 65-74  Age 75-84  Age 85+  \
# 20399  060759805011        104          5         63       36
# 10559  060379800331         13         13          0        0
# 10409  060379200311         18         18          0        0
# 467    060014251012         13          0         13        0
# 23907  060971524021        311         39        122      148
#
#        Total Senior Pop  Pct Seniors     BG20
# 20399               104   100.000000  9805011
# 10559                13   100.000000  9800331
# 10409                18   100.000000  9200311
# 467                  13   100.000000  4251012
# 23907               309    99.356913  1524021

# %%
#df2['BG20'] = df['BG20'].astype(int)
cities['BG20']=cities['BG20'].astype(int)

# %%
#lacity=cities.query("CITY_NAME == 'Los Angeles'").copy()

# %% [markdown]
# Eventually, we want to join our census data to block groups within the City of LA. First, let's clip the block groups down to the City level, then we can join it to the census data.

# %%
#finding a geojson file for census blocks 
#blocks = gpd.read_file('Census_Block_Groups_2020.geojson')
#blocks.size

# %% [markdown]
# Clip the county down to the city boundary

# %%
#blocks_clip = gpd.clip(blocks, cities)
#blocks_clip.size

# %% [markdown]
# Now, the block are only shown at the city level, not across the whole county. Let's continue to clean up the df.

# %%
#subset only the columns we need (fips, area, and geometry)
#blocks_clip = blocks_clip [['BG20', 'ShapeSTArea', 'geometry']]
#blocks_clip.head(5)

# %% [markdown]
# Now we want to join the census block boundaries within the city of LA to our census data. We have to create a FIPS column for the block boundaries, since they only show the block group number in "BG20".

# %%
# create a FIPS column
#blocks_clip['FIPS'] ='06' + '037' + blocks_clip['BG20']

# %%
#blocks_clip.head()
#ignore error!

# %% [markdown]
# The FIPS code worked, now we have a primary key to merge our Census data. Once it is merged, it will have the boundary geometry attached and will be mappable.

# %%
#join the ACS data with the geographic boundaries
blocks_age = cities.merge(df2, on="BG20", how='left')

# %%
blocks_age.head(5)
# Out:
#       BG20  Total_Pop  pop_density  official_area     neighborhood  \
# 0  9800391        0.0     0.000000       0.016862      Toluca Lake
# 1  9800311     1160.0   213.004200       5.445902        San Pedro
# 2  9800281        0.0     0.000000       6.679460      Westchester
# 3  9800261       16.0     2.988672       5.353549          Tujunga
# 4  9800241      200.0    64.759080       3.088370  Sepulveda Basin
#
#                                             geometry          FIPS  Total Pop  \
# 0  MULTIPOLYGON (((1966685.678 571125.893, 196670...  060379800391          0
# 1  POLYGON ((1973083.310 528189.940, 1973083.328 ...  060379800311       1160
# 2  POLYGON ((1958524.051 550029.553, 1958525.458 ...  060379800281          0
# 3  POLYGON ((1967614.398 586716.846, 1967615.058 ...  060379800261         16
# 4  POLYGON ((1952205.353 576098.621, 1952205.387 ...  060379800241        200
#
#    Age 65-74  Age 75-84  Age 85+  Total Senior Pop  Pct Seniors
# 0          0          0        0                 0     0.000000
# 1         83         27        0               110     9.482759
# 2          0          0        0                 0     0.000000
# 3          0          0        0                 0     0.000000
# 4          5         10       10                25    12.500000

# %%
cols_to_keep = ['BG20', 'FIPS', 'pop_density', 'official_area', 'neighborhood', 
 'Total Pop', 'Age 65-74', 'Age 75-84', 'Age 85+', 'Total Senior Pop', 'Pct Seniors', 'geometry'] 
blocks_age=blocks_age[cols_to_keep]

# %%
blocks_age.columns
# Out:
# Index(['BG20', 'FIPS', 'pop_density', 'official_area', 'neighborhood',
#        'Total Pop', 'Age 65-74', 'Age 75-84', 'Age 85+', 'Total Senior Pop',
#        'Pct Seniors', 'geometry'],
#       dtype='object')

# %%
blocks_age.columns = ['BG20', 'FIPS', 'Total Pop Density', 'Official Area', 'Neighborhood',
       'Total Pop', 'Age 65-74', 'Age 75-84', 'Age 85+', 'Total Senior Pop',
       'Pct Seniors', 'geometry']

# %%
blocks_age
# Out:
#          BG20          FIPS  Total Pop Density  Official Area  \
# 0     9800391  060379800391           0.000000       0.016862
# 1     9800311  060379800311         213.004200       5.445902
# 2     9800281  060379800281           0.000000       6.679460
# 3     9800261  060379800261           2.988672       5.353549
# 4     9800241  060379800241          64.759080       3.088370
# ...       ...           ...                ...            ...
# 2712  1011222  060371011222        4027.467000       0.406956
# 2713  1011221  060371011221        4248.138000       0.613916
# 2714  1011103  060371011103        5754.836000       0.131542
# 2715  1011102  060371011102       10903.520000       0.136837
# 2716  1011101  060371011101        9438.035000       0.172705
#
#          Neighborhood  Total Pop  Age 65-74  Age 75-84  Age 85+  \
# 0         Toluca Lake          0          0          0        0
# 1           San Pedro       1160         83         27        0
# 2         Westchester          0          0          0        0
# 3             Tujunga         16          0          0        0
# 4     Sepulveda Basin        200          5         10       10
# ...               ...        ...        ...        ...      ...
# 2712          Tujunga       1639        190         68       39
# 2713          Tujunga       2608        295        210      121
# 2714          Tujunga        757        106         59        0
# 2715          Tujunga       1492        316        112       22
# 2716          Tujunga       1630        208         34       16
#
#       Total Senior Pop  Pct Seniors  \
# 0                    0     0.000000
# 1                  110     9.482759
# 2                    0     0.000000
# 3                    0     0.000000
# 4                   25    12.500000
# ...                ...          ...
# 2712               297    18.120805
# 2713               626    24.003067
# 2714               165    21.796565
# 2715               450    30.160858
# 2716               258    15.828221
#
#                                                geometry
# 0     MULTIPOLYGON (((1966685.678 571125.893, 196670...
# 1     POLYGON ((1973083.310 528189.940, 1973083.328 ...
# 2     POLYGON ((1958524.051 550029.553, 1958525.458 ...
# 3     POLYGON ((1967614.398 586716.846, 1967615.058 ...
# 4     POLYGON ((1952205.353 576098.621, 1952205.387 ...
# ...                                                 ...
# 2712  POLYGON ((1973231.621 585529.766, 1973274.258 ...
# 2713  POLYGON ((1972070.991 585877.611, 1972075.990 ...
# 2714  POLYGON ((1972563.191 584701.132, 1972651.507 ...
# 2715  POLYGON ((1972286.047 584199.254, 1972287.705 ...
# 2716  POLYGON ((1973171.818 584658.528, 1973285.642 ...
#
# [2717 rows x 12 columns]

# %% [markdown]
# Now we have a mappable df of the total senior pop and percent population.

# %% [markdown]
# ## Creating columns for Area of Block Group and Population Density

# %% [markdown]
# In addition to percent of seniors, we want to see how many seniors per square mile are in each block group. To do that, we have to figure out the square mile area of each block group.
# The column ShapeSTArea shows the area of each block group shape, but it is in units of square meters. To change this to square miles, we will divide each by [2,590,000](https://www.google.com/search?q=square+meters+to+square+miles&rlz=1C1CHBF_enUS878US878&oq=square&aqs=chrome.0.69i59j69i57j0i131i433i512j0i433i512j0i131i433i512l2j69i60l2.994j0j7&sourceid=chrome&ie=UTF-8)

# %%
#blocks_age['Square Miles'] = blocks_age['ShapeSTArea']/2590000
#blocks_age.head(5)

# %% [markdown]
# Now we have a column with the square mileage of each census block group.

# %% [markdown]
# Now, for population density: Divide the total senior pop by the square mile of the block

# %%
#blocks_age['Pop Density'] = round(blocks_age['Total Senior Pop']/blocks_age['Square Miles']) #rounding so we get whole numbers
#blocks_age.head(5)

# %% [markdown]
# Now we have a df that shows percent of seniors in each block group and number of seniors per square mile in each block group. Let's see how the two compare on maps.

# %% [markdown]
# # Mapping

# %% [markdown]
# First, map the percentage of seniors over the total population.

# %%
blocks_age.plot(figsize=(12,10),
                column='Pct Seniors',
                legend=True,
                scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %% [markdown]
# This pattern shows that seniors might be more densly populated in the hills, a less dense area design-wise. Zooming in could be helpful.
#
# Now, compare this to the population density of seniors.

# %% [markdown]
# It is likely that the patterns here just reflect the overall population density per square mile, as smaller area block groups may have higher populations downtown. We should propbably use the "percent seniors" map to better express the different densities of seniors.

# %%
blocks_age.to_csv('Percent_Senior_Basemap.csv')

# %% [markdown]
# # Making a binary map to show the block groups with highest percentages of seniors

# %% [markdown]
# Rather than a chloropleth map, I would like to create a map of the city that only shows the census block groups that have the highest percentage of seniors. To do this, first we have to create a new column that shows the different categories of percentage. For example, 0-10%, 10-20%, etc. So if a tract has 14% seniors, it will fall into the 10-20% category. Then, we will create a loop that outputs binary maps for each interval category.

# %% [markdown]
# 1. Create a new column with categories for pct seniors.

# %%
#new column
blocks_age['pctcat'] = ''
blocks_age.head(10)
# Out:
#       BG20          FIPS  Total Pop Density  Official Area  \
# 0  9800391  060379800391           0.000000       0.016862
# 1  9800311  060379800311         213.004200       5.445902
# 2  9800281  060379800281           0.000000       6.679460
# 3  9800261  060379800261           2.988672       5.353549
# 4  9800241  060379800241          64.759080       3.088370
# 5  9800231  060379800231           0.000000       1.105886
# 6  9800221  060379800221           0.000000       2.156219
# 7  9800211  060379800211          17.693300       2.656373
# 8  9800201  060379800201           0.000000       3.294274
# 9  9800191  060379800191           3.866498      17.069712
#
#            Neighborhood  Total Pop  Age 65-74  Age 75-84  Age 85+  \
# 0           Toluca Lake          0          0          0        0
# 1             San Pedro       1160         83         27        0
# 2           Westchester          0          0          0        0
# 3               Tujunga         16          0          0        0
# 4       Sepulveda Basin        200          5         10       10
# 5  Chatsworth Reservoir          0          0          0        0
# 6         Granada Hills          0          0          0        0
# 7            Hansen Dam         47          0          0        0
# 8          Shadow Hills          0          0          0        0
# 9     Pacific Palisades         66         20          0        5
#
#    Total Senior Pop  Pct Seniors  \
# 0                 0     0.000000
# 1               110     9.482759
# 2                 0     0.000000
# 3                 0     0.000000
# 4                25    12.500000
# 5                 0     0.000000
# 6                 0     0.000000
# 7                 0     0.000000
# 8                 0     0.000000
# 9                25    37.878788
#
#                                             geometry pctcat
# 0  MULTIPOLYGON (((1966685.678 571125.893, 196670...
# 1  POLYGON ((1973083.310 528189.940, 1973083.328 ...
# 2  POLYGON ((1958524.051 550029.553, 1958525.458 ...
# 3  POLYGON ((1967614.398 586716.846, 1967615.058 ...
# 4  POLYGON ((1952205.353 576098.621, 1952205.387 ...
# 5  POLYGON ((1940299.007 581596.678, 1940325.417 ...
# 6  POLYGON ((1953733.729 589774.434, 1953736.412 ...
# 7  POLYGON ((1962999.185 584965.251, 1963005.172 ...
# 8  POLYGON ((1968290.686 579587.470, 1968312.470 ...
# 9  POLYGON ((1944694.354 563878.698, 1944699.490 ...

# %% [markdown]
# 2. Add the interval of choice depending on the value in Pct Seniors using queries

# %%
blocks_age.loc[blocks_age['Pct Seniors'].between(0,10), 'pctcat'] = '0%-10%'
blocks_age.loc[blocks_age['Pct Seniors'].between(10,20), 'pctcat'] = '10%-20%'
#blocks_age.loc[blocks_age['Pct Seniors'].between(20,40), 'pctcat'] = '20%-40%'
blocks_age.loc[blocks_age['Pct Seniors'] > 20, 'pctcat'] = '20%+'
blocks_age.sample(5)
# Out:
#          BG20          FIPS  Total Pop Density  Official Area  \
# 1534  1915001  060371915001          10579.490       0.143863
# 1261  2073062  060372073062         110881.100       0.009893
# 686   2364001  060372364001           7905.327       0.168620
# 1041  2161003  060372161003           9818.063       0.059584
# 2064  1286023  060371286023           5328.741       0.250341
#
#                 Neighborhood  Total Pop  Age 65-74  Age 75-84  Age 85+  \
# 1534          East Hollywood       1522        120         66       59
# 1261                Downtown       1097        101          0        0
# 686   Baldwin Hills/Crenshaw       1333        160         63        7
# 1041            Mid-Wilshire        585         22          4        0
# 2064            Sherman Oaks       1334        190         23        9
#
#       Total Senior Pop  Pct Seniors  \
# 1534               245    16.097240
# 1261               101     9.206928
# 686                230    17.254314
# 1041                26     4.444444
# 2064               222    16.641679
#
#                                                geometry   pctcat
# 1534  POLYGON ((1972588.832 565266.236, 1972677.892 ...  10%-20%
# 1261  POLYGON ((1977074.735 560906.765, 1977125.422 ...   0%-10%
# 686   POLYGON ((1967203.419 556360.130, 1967217.452 ...  10%-20%
# 1041  POLYGON ((1968287.166 561515.424, 1968287.293 ...   0%-10%
# 2064  POLYGON ((1959537.263 574643.770, 1959637.940 ...  10%-20%

# %% [markdown]
# now we have a column that shows each interval category that the percentage falls into.

# %% [markdown]
# 3. Make a new list of all unique pctcat

# %%
pctcats = blocks_age['pctcat'].unique().tolist()
pctcats
# Out:
# ['0%-10%', '10%-20%', '20%+']

# %% [markdown]
# This list shows all of our categories and can be used to create a loop.

# %% [markdown]
# 4. Map it with a loop!

# %%
#blocks_age[blocks_age['pctcat'].as_type(int)

# %%
for pct in pctcats:
    fig, ax = plt.subplots(figsize=(8,8))

    # create the map plot
    blocks_age.plot(ax=ax,
            color='#bababa')

    # create the map plot
    blocks_age[blocks_age['pctcat'] == pct].plot(ax=ax,
            # column='pctcat',
            color='#018571')

    # add a title
    ax.set_title('Census Blocks with ' + pct + ' ' + 'Residents Age 65+')
    ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs='epsg:6423')
    # get rid of the axis
    ax.axis('off');

# %% [markdown]
# Now we have binary maps of each category of senior density. These can be adjusted to show different categories and percentages. The 40%+ map picks out areas with extremely high concentrations of seniors, and the 20-40% map shows more widespread distribution of seniors. Now, let's plot the different percentages in a single chart.

# %%
blocks_age.plot.bar(x = 'BG20', 
                    y = 'Pct Seniors', 
                    title = 'Percent Residents age 65+ Per Census Block', 
                    legend = False, 
                    color='#80cdc1')
# Out:
# <AxesSubplot: title={'center': 'Percent Residents age 65+ Per Census Block'}, xlabel='BG20'>

# %% [markdown]
# This chart isn't very useful or readable, but shows what our maps already told us, that most of the groups were under 20% with a few up to 40%+. Let's instead look at the top 10 block groups to see what the highest percentages of seniors are.

# %%
#Sort to see the top groups
blocks_age.sort_values('Pct Seniors', inplace=True)
blocks_age.head()
# Out:
#          BG20          FIPS  Total Pop Density  Official Area Neighborhood  \
# 0     9800391  060379800391               0.00       0.016862  Toluca Lake
# 429   2653061  060372653061           49579.91       0.036002     Westwood
# 1916  1349072  060371349072           47259.15       0.049324  Canoga Park
# 1917  1349071  060371349071           10045.87       0.101833  Canoga Park
# 434   2653031  060372653031           90148.52       0.018381     Westwood
#
#       Total Pop  Age 65-74  Age 75-84  Age 85+  Total Senior Pop  Pct Seniors  \
# 0             0          0          0        0                 0          0.0
# 429        1785          0          0        0                 0          0.0
# 1916       2331          0          0        0                 0          0.0
# 1917       1023          0          0        0                 0          0.0
# 434        1657          0          0        0                 0          0.0
#
#                                                geometry  pctcat
# 0     MULTIPOLYGON (((1966685.678 571125.893, 196670...  0%-10%
# 429   POLYGON ((1958434.943 562866.663, 1958444.326 ...  0%-10%
# 1916  POLYGON ((1945227.228 577118.260, 1945360.047 ...  0%-10%
# 1917  POLYGON ((1944971.915 577119.329, 1945117.453 ...  0%-10%
# 434   POLYGON ((1958102.084 563362.770, 1958121.475 ...  0%-10%

# %%
#plot the df
blocks_age.sort_values('Pct Seniors', inplace=True, ascending=False)

fig, ax = plt.subplots(figsize=(12,4))

blocks_age[:10].plot.bar(ax=ax,
                                      x='BG20',
                                      y='Pct Seniors',
                                      legend=False,
                                      color='#80cdc1'
                                      )
ax.set_xlabel('Census Block Number') # override x label
ax.set_ylabel('Percent Population age 65+') # override y label
ax.set_title("Percent Population 65+: Top 10 Census Blocks",fontsize=14,pad=10); # multi-line title with padding

# %% [markdown]
# Now we see that there is one block group with 100% seniors, and the highest are up to 60% or more seniors.

# %%
blocks_age.sort_values('Pct Seniors', inplace=True, ascending=False)

fig, ax = plt.subplots(figsize=(7,7))
blocks_age[:10].plot(ax=ax, 
                              color='#018571')
ax.set_title('Block Groups with Highest Population of Residents Age 65+')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs='epsg:6423')
ax.axis('off');

# %%
blocks_age.to_file('seniors_update.geojson', driver='GeoJSON')
